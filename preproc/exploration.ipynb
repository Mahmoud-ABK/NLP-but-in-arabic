# %% [markdown]
# # Exploration de pyarabic.araby

# %%
from pyarabic.araby import strip_tashkeel, strip_tatweel,TASHKEEL,TATWEEL

# %%
TASHKEEL
# Out:
# ('ً', 'ٌ', 'ٍ', 'َ', 'ُ', 'ِ', 'ْ', 'ّ')

# %%
TATWEEL
# Out:
# 'ـ'

# %%
strip_tashkeel??
# Out:
# Signature: strip_tashkeel(text)
# Source:
# def strip_tashkeel(text):
#     """Strip vowels from a text, include Shadda.
#     The striped marks are :
#         - FATHA, DAMMA, KASRA
#         - SUKUN
#         - SHADDA
#         - FATHATAN, DAMMATAN, KASRATAN,, , .
#
#     Example:
#         >>> text = u"الْعَرَبِيّةُ"
#         >>> strip_tashkeel(text)
#         العربية
#
#     @param text: arabic text.
#     @type text: unicode.
#     @return: return a striped text.
#     @rtype: unicode.
#     """
#     if not text:
#         return text
#     elif is_vocalized(text):
#         for char in TASHKEEL:
#             text = text.replace(char, '')
#     return text
# File:      ~/anaconda3/envs/data-treat/lib/python3.11/site-packages/pyarabic/araby.py
# Type:      function

# %%
strip_tatweel??
# Out:
# Signature: strip_tatweel(text)
# Source:
# def strip_tatweel(text):
#     """
#     Strip tatweel from a text and return a result text.
#
#     Example:
#         >>> text = u"العـــــربية"
#         >>> strip_tatweel(text)
#         العربية
#
#     @param text: arabic text.
#     @type text: unicode.
#     @return: return a striped text.
#     @rtype: unicode.
#
#     """
#     return text.replace(TATWEEL, '')
# File:      ~/anaconda3/envs/data-treat/lib/python3.11/site-packages/pyarabic/araby.py
# Type:      function

# %% [markdown]
# # Exploration de arabicstopwords

# %%
import arabicstopwords.arabicstopwords as stp #more range of arabic stop words

# %%
stp.STOPWORDS
# Out:
# {'أن': [{'word': 'أن',
#    'vocalized': 'أَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': ''},
#   {'word': 'أن',
#    'vocalized': 'أَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': ''}],
#  'أنك': [{'word': 'أنك',
#    'vocalized': 'أَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'مضاف'},
#   {'word': 'أنك',
#    'vocalized': 'أَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'مضاف'}],
#  'أنكما': [{'word': 'أنكما',
#    'vocalized': 'أَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'مضاف'}],
#  'أنكم': [{'word': 'أنكم',
#    'vocalized': 'أَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'مضاف'}],
#  'أنكن': [{'word': 'أنكن',
#    'vocalized': 'أَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'مضاف'}],
#  'أننا': [{'word': 'أننا',
#    'vocalized': 'أَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'مضاف'}],
#  'أنها': [{'word': 'أنها',
#    'vocalized': 'أَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'مضاف'}],
#  'أنه': [{'word': 'أنه',
#    'vocalized': 'أَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'مضاف:لايجر:T'}],
#  'أنهما': [{'word': 'أنهما',
#    'vocalized': 'أَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'مضاف:لايجر'}],
#  'أنهم': [{'word': 'أنهم',
#    'vocalized': 'أَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'مضاف:لايجر'}],
#  'أنهن': [{'word': 'أنهن',
#    'vocalized': 'أَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'مضاف:لايجر'}],
#  'أني': [{'word': 'أني',
#    'vocalized': 'أَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': '-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'مضاف'}],
#  'بأن': [{'word': 'بأن',
#    'vocalized': 'بِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'},
#   {'word': 'بأن',
#    'vocalized': 'بِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'بأنك': [{'word': 'بأنك',
#    'vocalized': 'بِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'},
#   {'word': 'بأنك',
#    'vocalized': 'بِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'}],
#  'بأنكما': [{'word': 'بأنكما',
#    'vocalized': 'بِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:مضاف'}],
#  'بأنكم': [{'word': 'بأنكم',
#    'vocalized': 'بِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:مضاف'}],
#  'بأنكن': [{'word': 'بأنكن',
#    'vocalized': 'بِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:مضاف'}],
#  'بأننا': [{'word': 'بأننا',
#    'vocalized': 'بِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:مضاف'}],
#  'بأنها': [{'word': 'بأنها',
#    'vocalized': 'بِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:مضاف'}],
#  'بأنه': [{'word': 'بأنه',
#    'vocalized': 'بِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:مضاف:لايجر:T'}],
#  'بأنهما': [{'word': 'بأنهما',
#    'vocalized': 'بِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:مضاف:لايجر'}],
#  'بأنهم': [{'word': 'بأنهم',
#    'vocalized': 'بِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:مضاف:لايجر'}],
#  'بأنهن': [{'word': 'بأنهن',
#    'vocalized': 'بِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:مضاف:لايجر'}],
#  'بأني': [{'word': 'بأني',
#    'vocalized': 'بِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ب-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:مضاف'}],
#  'فأن': [{'word': 'فأن',
#    'vocalized': 'فَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'},
#   {'word': 'فأن',
#    'vocalized': 'فَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'فأنك': [{'word': 'فأنك',
#    'vocalized': 'فَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'},
#   {'word': 'فأنك',
#    'vocalized': 'فَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأنكما': [{'word': 'فأنكما',
#    'vocalized': 'فَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأنكم': [{'word': 'فأنكم',
#    'vocalized': 'فَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأنكن': [{'word': 'فأنكن',
#    'vocalized': 'فَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأننا': [{'word': 'فأننا',
#    'vocalized': 'فَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأنها': [{'word': 'فأنها',
#    'vocalized': 'فَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فأنه': [{'word': 'فأنه',
#    'vocalized': 'فَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:مضاف:لايجر:T'}],
#  'فأنهما': [{'word': 'فأنهما',
#    'vocalized': 'فَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فأنهم': [{'word': 'فأنهم',
#    'vocalized': 'فَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فأنهن': [{'word': 'فأنهن',
#    'vocalized': 'فَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فأني': [{'word': 'فأني',
#    'vocalized': 'فَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ف-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فبأن': [{'word': 'فبأن',
#    'vocalized': 'فَبِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'},
#   {'word': 'فبأن',
#    'vocalized': 'فَبِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فبأنك': [{'word': 'فبأنك',
#    'vocalized': 'فَبِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فبأنك',
#    'vocalized': 'فَبِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأنكما': [{'word': 'فبأنكما',
#    'vocalized': 'فَبِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأنكم': [{'word': 'فبأنكم',
#    'vocalized': 'فَبِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأنكن': [{'word': 'فبأنكن',
#    'vocalized': 'فَبِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأننا': [{'word': 'فبأننا',
#    'vocalized': 'فَبِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأنها': [{'word': 'فبأنها',
#    'vocalized': 'فَبِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فبأنه': [{'word': 'فبأنه',
#    'vocalized': 'فَبِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر:T'}],
#  'فبأنهما': [{'word': 'فبأنهما',
#    'vocalized': 'فَبِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فبأنهم': [{'word': 'فبأنهم',
#    'vocalized': 'فَبِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فبأنهن': [{'word': 'فبأنهن',
#    'vocalized': 'فَبِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فبأني': [{'word': 'فبأني',
#    'vocalized': 'فَبِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فب-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فكأن': [{'word': 'فكأن',
#    'vocalized': 'فَكَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'},
#   {'word': 'فكأن',
#    'vocalized': 'فَكَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'},
#   {'word': 'فكأن',
#    'vocalized': 'فَكَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فكأنك': [{'word': 'فكأنك',
#    'vocalized': 'فَكَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنك',
#    'vocalized': 'فَكَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنك',
#    'vocalized': 'فَكَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'},
#   {'word': 'فكأنك',
#    'vocalized': 'فَكَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأنكما': [{'word': 'فكأنكما',
#    'vocalized': 'فَكَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنكما',
#    'vocalized': 'فَكَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأنكم': [{'word': 'فكأنكم',
#    'vocalized': 'فَكَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنكم',
#    'vocalized': 'فَكَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأنكن': [{'word': 'فكأنكن',
#    'vocalized': 'فَكَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنكن',
#    'vocalized': 'فَكَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأننا': [{'word': 'فكأننا',
#    'vocalized': 'فَكَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأننا',
#    'vocalized': 'فَكَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأنها': [{'word': 'فكأنها',
#    'vocalized': 'فَكَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأنها',
#    'vocalized': 'فَكَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فكأنه': [{'word': 'فكأنه',
#    'vocalized': 'فَكَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر:T'},
#   {'word': 'فكأنه',
#    'vocalized': 'فَكَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:مضاف:لايجر:T'}],
#  'فكأنهما': [{'word': 'فكأنهما',
#    'vocalized': 'فَكَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'},
#   {'word': 'فكأنهما',
#    'vocalized': 'فَكَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فكأنهم': [{'word': 'فكأنهم',
#    'vocalized': 'فَكَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'},
#   {'word': 'فكأنهم',
#    'vocalized': 'فَكَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فكأنهن': [{'word': 'فكأنهن',
#    'vocalized': 'فَكَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'},
#   {'word': 'فكأنهن',
#    'vocalized': 'فَكَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'فكأني': [{'word': 'فكأني',
#    'vocalized': 'فَكَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فك-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فكأني',
#    'vocalized': 'فَكَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'ف-',
#    'stem': 'كأن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'فلأن': [{'word': 'فلأن',
#    'vocalized': 'فَلِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'},
#   {'word': 'فلأن',
#    'vocalized': 'فَلَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:قسم'},
#   {'word': 'فلأن',
#    'vocalized': 'فَلِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فلأنك': [{'word': 'فلأنك',
#    'vocalized': 'فَلِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'},
#   {'word': 'فلأنك',
#    'vocalized': 'فَلِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأنكما': [{'word': 'فلأنكما',
#    'vocalized': 'فَلِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأنكم': [{'word': 'فلأنكم',
#    'vocalized': 'فَلِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأنكن': [{'word': 'فلأنكن',
#    'vocalized': 'فَلِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأننا': [{'word': 'فلأننا',
#    'vocalized': 'فَلِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأنها': [{'word': 'فلأنها',
#    'vocalized': 'فَلِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'فلأنه': [{'word': 'فلأنه',
#    'vocalized': 'فَلِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر:T'}],
#  'فلأنهما': [{'word': 'فلأنهما',
#    'vocalized': 'فَلِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فلأنهم': [{'word': 'فلأنهم',
#    'vocalized': 'فَلِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فلأنهن': [{'word': 'فلأنهن',
#    'vocalized': 'فَلِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:جر:مضاف:لايجر'}],
#  'فلأني': [{'word': 'فلأني',
#    'vocalized': 'فَلِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'فل-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:جر:مضاف'}],
#  'كأن': [{'word': 'كأن',
#    'vocalized': 'كَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'},
#   {'word': 'كأن',
#    'vocalized': 'كَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-',
#    'tags': ''},
#   {'word': 'كأن',
#    'vocalized': 'كَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'كأنك': [{'word': 'كأنك',
#    'vocalized': 'كَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنك',
#    'vocalized': 'كَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنك',
#    'vocalized': 'كَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'مضاف'},
#   {'word': 'كأنك',
#    'vocalized': 'كَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'مضاف'}],
#  'كأنكما': [{'word': 'كأنكما',
#    'vocalized': 'كَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنكما',
#    'vocalized': 'كَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-كما',
#    'tags': 'مضاف'}],
#  'كأنكم': [{'word': 'كأنكم',
#    'vocalized': 'كَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنكم',
#    'vocalized': 'كَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-كم',
#    'tags': 'مضاف'}],
#  'كأنكن': [{'word': 'كأنكن',
#    'vocalized': 'كَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنكن',
#    'vocalized': 'كَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-كن',
#    'tags': 'مضاف'}],
#  'كأننا': [{'word': 'كأننا',
#    'vocalized': 'كَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأننا',
#    'vocalized': 'كَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-نا',
#    'tags': 'مضاف'}],
#  'كأنها': [{'word': 'كأنها',
#    'vocalized': 'كَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأنها',
#    'vocalized': 'كَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-ها',
#    'tags': 'مضاف'}],
#  'كأنه': [{'word': 'كأنه',
#    'vocalized': 'كَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:مضاف:لايجر:T'},
#   {'word': 'كأنه',
#    'vocalized': 'كَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-ه',
#    'tags': 'مضاف:لايجر:T'}],
#  'كأنهما': [{'word': 'كأنهما',
#    'vocalized': 'كَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:مضاف:لايجر'},
#   {'word': 'كأنهما',
#    'vocalized': 'كَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-هما',
#    'tags': 'مضاف:لايجر'}],
#  'كأنهم': [{'word': 'كأنهم',
#    'vocalized': 'كَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:مضاف:لايجر'},
#   {'word': 'كأنهم',
#    'vocalized': 'كَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-هم',
#    'tags': 'مضاف:لايجر'}],
#  'كأنهن': [{'word': 'كأنهن',
#    'vocalized': 'كَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:مضاف:لايجر'},
#   {'word': 'كأنهن',
#    'vocalized': 'كَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-هن',
#    'tags': 'مضاف:لايجر'}],
#  'كأني': [{'word': 'كأني',
#    'vocalized': 'كَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ك-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:مضاف'},
#   {'word': 'كأني',
#    'vocalized': 'كَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': '-',
#    'stem': 'كأن',
#    'encletic': '-ي',
#    'tags': 'مضاف'}],
#  'لأن': [{'word': 'لأن',
#    'vocalized': 'لِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'},
#   {'word': 'لأن',
#    'vocalized': 'لِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر'},
#   {'word': 'لأن',
#    'vocalized': 'لَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'قسم'}],
#  'لأنك': [{'word': 'لأنك',
#    'vocalized': 'لِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'},
#   {'word': 'لأنك',
#    'vocalized': 'لِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:مضاف'}],
#  'لأنكما': [{'word': 'لأنكما',
#    'vocalized': 'لِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:مضاف'}],
#  'لأنكم': [{'word': 'لأنكم',
#    'vocalized': 'لِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:مضاف'}],
#  'لأنكن': [{'word': 'لأنكن',
#    'vocalized': 'لِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:مضاف'}],
#  'لأننا': [{'word': 'لأننا',
#    'vocalized': 'لِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:مضاف'}],
#  'لأنها': [{'word': 'لأنها',
#    'vocalized': 'لِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:مضاف'}],
#  'لأنه': [{'word': 'لأنه',
#    'vocalized': 'لِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:مضاف:لايجر:T'}],
#  'لأنهما': [{'word': 'لأنهما',
#    'vocalized': 'لِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:مضاف:لايجر'}],
#  'لأنهم': [{'word': 'لأنهم',
#    'vocalized': 'لِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:مضاف:لايجر'}],
#  'لأنهن': [{'word': 'لأنهن',
#    'vocalized': 'لِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:مضاف:لايجر'}],
#  'لأني': [{'word': 'لأني',
#    'vocalized': 'لِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ل-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:مضاف'}],
#  'وأن': [{'word': 'وأن',
#    'vocalized': 'وَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'},
#   {'word': 'وأن',
#    'vocalized': 'وَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وأنك': [{'word': 'وأنك',
#    'vocalized': 'وَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'},
#   {'word': 'وأنك',
#    'vocalized': 'وَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأنكما': [{'word': 'وأنكما',
#    'vocalized': 'وَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأنكم': [{'word': 'وأنكم',
#    'vocalized': 'وَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأنكن': [{'word': 'وأنكن',
#    'vocalized': 'وَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأننا': [{'word': 'وأننا',
#    'vocalized': 'وَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأنها': [{'word': 'وأنها',
#    'vocalized': 'وَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وأنه': [{'word': 'وأنه',
#    'vocalized': 'وَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:مضاف:لايجر:T'}],
#  'وأنهما': [{'word': 'وأنهما',
#    'vocalized': 'وَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وأنهم': [{'word': 'وأنهم',
#    'vocalized': 'وَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وأنهن': [{'word': 'وأنهن',
#    'vocalized': 'وَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وأني': [{'word': 'وأني',
#    'vocalized': 'وَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'و-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وبأن': [{'word': 'وبأن',
#    'vocalized': 'وَبِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'},
#   {'word': 'وبأن',
#    'vocalized': 'وَبِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'وبأنك': [{'word': 'وبأنك',
#    'vocalized': 'وَبِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وبأنك',
#    'vocalized': 'وَبِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأنكما': [{'word': 'وبأنكما',
#    'vocalized': 'وَبِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأنكم': [{'word': 'وبأنكم',
#    'vocalized': 'وَبِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأنكن': [{'word': 'وبأنكن',
#    'vocalized': 'وَبِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأننا': [{'word': 'وبأننا',
#    'vocalized': 'وَبِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأنها': [{'word': 'وبأنها',
#    'vocalized': 'وَبِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وبأنه': [{'word': 'وبأنه',
#    'vocalized': 'وَبِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر:T'}],
#  'وبأنهما': [{'word': 'وبأنهما',
#    'vocalized': 'وَبِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'وبأنهم': [{'word': 'وبأنهم',
#    'vocalized': 'وَبِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'وبأنهن': [{'word': 'وبأنهن',
#    'vocalized': 'وَبِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'وبأني': [{'word': 'وبأني',
#    'vocalized': 'وَبِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وب-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'وكأن': [{'word': 'وكأن',
#    'vocalized': 'وَكَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'},
#   {'word': 'وكأن',
#    'vocalized': 'وَكَأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'},
#   {'word': 'وكأن',
#    'vocalized': 'وَكَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'وكأنك': [{'word': 'وكأنك',
#    'vocalized': 'وَكَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنك',
#    'vocalized': 'وَكَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنك',
#    'vocalized': 'وَكَأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'},
#   {'word': 'وكأنك',
#    'vocalized': 'وَكَأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-ك',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأنكما': [{'word': 'وكأنكما',
#    'vocalized': 'وَكَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنكما',
#    'vocalized': 'وَكَأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-كما',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأنكم': [{'word': 'وكأنكم',
#    'vocalized': 'وَكَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنكم',
#    'vocalized': 'وَكَأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-كم',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأنكن': [{'word': 'وكأنكن',
#    'vocalized': 'وَكَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنكن',
#    'vocalized': 'وَكَأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-كن',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأننا': [{'word': 'وكأننا',
#    'vocalized': 'وَكَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأننا',
#    'vocalized': 'وَكَأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-نا',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأنها': [{'word': 'وكأنها',
#    'vocalized': 'وَكَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأنها',
#    'vocalized': 'وَكَأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-ها',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'وكأنه': [{'word': 'وكأنه',
#    'vocalized': 'وَكَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر:T'},
#   {'word': 'وكأنه',
#    'vocalized': 'وَكَأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-ه',
#    'tags': 'معطوف:عطف:مضاف:لايجر:T'}],
#  'وكأنهما': [{'word': 'وكأنهما',
#    'vocalized': 'وَكَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'},
#   {'word': 'وكأنهما',
#    'vocalized': 'وَكَأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-هما',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وكأنهم': [{'word': 'وكأنهم',
#    'vocalized': 'وَكَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'},
#   {'word': 'وكأنهم',
#    'vocalized': 'وَكَأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-هم',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وكأنهن': [{'word': 'وكأنهن',
#    'vocalized': 'وَكَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'},
#   {'word': 'وكأنهن',
#    'vocalized': 'وَكَأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-هن',
#    'tags': 'معطوف:عطف:مضاف:لايجر'}],
#  'وكأني': [{'word': 'وكأني',
#    'vocalized': 'وَكَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'وك-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'وكأني',
#    'vocalized': 'وَكَأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'كأن',
#    'procletic': 'و-',
#    'stem': 'كأن',
#    'encletic': '-ي',
#    'tags': 'معطوف:عطف:مضاف'}],
#  'ولأن': [{'word': 'ولأن',
#    'vocalized': 'وَلِأَنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'},
#   {'word': 'ولأن',
#    'vocalized': 'وَلَأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'قسم:معطوف:عطف'},
#   {'word': 'ولأن',
#    'vocalized': 'وَلِأَن',
#    'type': 'حرف',
#    'category': 'حرف نصب',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'ولأنك': [{'word': 'ولأنك',
#    'vocalized': 'وَلِأَنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'},
#   {'word': 'ولأنك',
#    'vocalized': 'وَلِأَنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-ك',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأنكما': [{'word': 'ولأنكما',
#    'vocalized': 'وَلِأَنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-كما',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأنكم': [{'word': 'ولأنكم',
#    'vocalized': 'وَلِأَنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-كم',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأنكن': [{'word': 'ولأنكن',
#    'vocalized': 'وَلِأَنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-كن',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأننا': [{'word': 'ولأننا',
#    'vocalized': 'وَلِأَنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-نا',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأنها': [{'word': 'ولأنها',
#    'vocalized': 'وَلِأَنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-ها',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'ولأنه': [{'word': 'ولأنه',
#    'vocalized': 'وَلِأَنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-ه',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر:T'}],
#  'ولأنهما': [{'word': 'ولأنهما',
#    'vocalized': 'وَلِأَنّهُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-هما',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'ولأنهم': [{'word': 'ولأنهم',
#    'vocalized': 'وَلِأَنّهُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-هم',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'ولأنهن': [{'word': 'ولأنهن',
#    'vocalized': 'وَلِأَنّهُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-هن',
#    'tags': 'جر:معطوف:عطف:مضاف:لايجر'}],
#  'ولأني': [{'word': 'ولأني',
#    'vocalized': 'وَلِأَنِّي',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'أن',
#    'procletic': 'ول-',
#    'stem': 'أن',
#    'encletic': '-ي',
#    'tags': 'جر:معطوف:عطف:مضاف'}],
#  'إن': [{'word': 'إن',
#    'vocalized': 'إِنّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-',
#    'tags': ''},
#   {'word': 'إن',
#    'vocalized': 'إِن',
#    'type': 'حرف',
#    'category': 'المشبهة بليس',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-',
#    'tags': ''},
#   {'word': 'إن',
#    'vocalized': 'إِن',
#    'type': 'حرف',
#    'category': 'حرف جزم',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-',
#    'tags': ''},
#   {'word': 'إن',
#    'vocalized': 'إِن',
#    'type': 'حرف',
#    'category': 'حرف شرط',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-',
#    'tags': ''}],
#  'إنك': [{'word': 'إنك',
#    'vocalized': 'إِنّكَ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-ك',
#    'tags': 'مضاف'},
#   {'word': 'إنك',
#    'vocalized': 'إِنّكِ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-ك',
#    'tags': 'مضاف'}],
#  'إنكما': [{'word': 'إنكما',
#    'vocalized': 'إِنّكُمَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-كما',
#    'tags': 'مضاف'}],
#  'إنكم': [{'word': 'إنكم',
#    'vocalized': 'إِنّكُمْ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-كم',
#    'tags': 'مضاف'}],
#  'إنكن': [{'word': 'إنكن',
#    'vocalized': 'إِنّكُنَّ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-كن',
#    'tags': 'مضاف'}],
#  'إننا': [{'word': 'إننا',
#    'vocalized': 'إِنّنَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-نا',
#    'tags': 'مضاف'}],
#  'إنها': [{'word': 'إنها',
#    'vocalized': 'إِنّهَا',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-ها',
#    'tags': 'مضاف'}],
#  'إنه': [{'word': 'إنه',
#    'vocalized': 'إِنّهُ',
#    'type': 'حرف',
#    'category': 'إن و أخواتها',
#    'original': 'إن',
#    'procletic': '-',
#    'stem': 'إن',
#    'encletic': '-ه',
# ...
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'أولأولالك': [{'word': 'أولأولالك',
#    'vocalized': 'أَوَلِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'أول-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'بأولالك': [{'word': 'بأولالك',
#    'vocalized': 'بِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'ب-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'فأولالك': [{'word': 'فأولالك',
#    'vocalized': 'فَأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'ف-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'فبأولالك': [{'word': 'فبأولالك',
#    'vocalized': 'فَبِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'فب-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فكأولالك': [{'word': 'فكأولالك',
#    'vocalized': 'فَكَأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'فك-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فلأولالك': [{'word': 'فلأولالك',
#    'vocalized': 'فَلِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'فل-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'كأولالك': [{'word': 'كأولالك',
#    'vocalized': 'كَأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'ك-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'لأولالك': [{'word': 'لأولالك',
#    'vocalized': 'لِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'ل-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'وأولالك': [{'word': 'وأولالك',
#    'vocalized': 'وَأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'و-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وبأولالك': [{'word': 'وبأولالك',
#    'vocalized': 'وَبِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'وب-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'وكأولالك': [{'word': 'وكأولالك',
#    'vocalized': 'وَكَأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'وك-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'ولأولالك': [{'word': 'ولأولالك',
#    'vocalized': 'وَلِأُولَالِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'أولالك',
#    'procletic': 'ول-',
#    'stem': 'أولالك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'تان': [{'word': 'تان',
#    'vocalized': 'تَان',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تان',
#    'procletic': '-',
#    'stem': 'تان',
#    'encletic': '-',
#    'tags': ''}],
#  'فتان': [{'word': 'فتان',
#    'vocalized': 'فَتَان',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تان',
#    'procletic': 'ف-',
#    'stem': 'تان',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وتان': [{'word': 'وتان',
#    'vocalized': 'وَتَان',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تان',
#    'procletic': 'و-',
#    'stem': 'تان',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'تانك': [{'word': 'تانك',
#    'vocalized': 'تَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': '-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': ''}],
#  'بتانك': [{'word': 'بتانك',
#    'vocalized': 'بِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'ب-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'فتانك': [{'word': 'فتانك',
#    'vocalized': 'فَتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'ف-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'فبتانك': [{'word': 'فبتانك',
#    'vocalized': 'فَبِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'فب-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فكتانك': [{'word': 'فكتانك',
#    'vocalized': 'فَكَتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'فك-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فلتانك': [{'word': 'فلتانك',
#    'vocalized': 'فَلِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'فل-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'كتانك': [{'word': 'كتانك',
#    'vocalized': 'كَتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'ك-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'لتانك': [{'word': 'لتانك',
#    'vocalized': 'لِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'ل-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'وتانك': [{'word': 'وتانك',
#    'vocalized': 'وَتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'و-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وبتانك': [{'word': 'وبتانك',
#    'vocalized': 'وَبِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'وب-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'وكتانك': [{'word': 'وكتانك',
#    'vocalized': 'وَكَتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'وك-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'ولتانك': [{'word': 'ولتانك',
#    'vocalized': 'وَلِتَانِك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تانك',
#    'procletic': 'ول-',
#    'stem': 'تانك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'تلك': [{'word': 'تلك',
#    'vocalized': 'تِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': '-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': ''}],
#  'أكتلك': [{'word': 'أكتلك',
#    'vocalized': 'أكَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أتلك': [{'word': 'أتلك',
#    'vocalized': 'أَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أ-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام'}],
#  'أبتلك': [{'word': 'أبتلك',
#    'vocalized': 'أَبِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أفتلك': [{'word': 'أفتلك',
#    'vocalized': 'أَفَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أف-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف'}],
#  'أفبتلك': [{'word': 'أفبتلك',
#    'vocalized': 'أَفَبِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أفب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'أفكتلك': [{'word': 'أفكتلك',
#    'vocalized': 'أَفَكَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أفك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'أفلتلك': [{'word': 'أفلتلك',
#    'vocalized': 'أَفَلِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أفل-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'ألتلك': [{'word': 'ألتلك',
#    'vocalized': 'أَلِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أل-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أوتلك': [{'word': 'أوتلك',
#    'vocalized': 'أَوَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أو-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:استفهام'}],
#  'أوبتلك': [{'word': 'أوبتلك',
#    'vocalized': 'أَوَبِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أوب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'أوكتلك': [{'word': 'أوكتلك',
#    'vocalized': 'أَوَكَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أوك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'أولتلك': [{'word': 'أولتلك',
#    'vocalized': 'أَوَلِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'أول-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'بتلك': [{'word': 'بتلك',
#    'vocalized': 'بِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'ب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'فتلك': [{'word': 'فتلك',
#    'vocalized': 'فَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'ف-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'فبتلك': [{'word': 'فبتلك',
#    'vocalized': 'فَبِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'فب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فكتلك': [{'word': 'فكتلك',
#    'vocalized': 'فَكَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'فك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فلتلك': [{'word': 'فلتلك',
#    'vocalized': 'فَلِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'فل-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'كتلك': [{'word': 'كتلك',
#    'vocalized': 'كَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'ك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'لتلك': [{'word': 'لتلك',
#    'vocalized': 'لِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'ل-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'وتلك': [{'word': 'وتلك',
#    'vocalized': 'وَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'و-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وبتلك': [{'word': 'وبتلك',
#    'vocalized': 'وَبِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'وب-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'وكتلك': [{'word': 'وكتلك',
#    'vocalized': 'وَكَتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'وك-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'ولتلك': [{'word': 'ولتلك',
#    'vocalized': 'وَلِتِلْك',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلك',
#    'procletic': 'ول-',
#    'stem': 'تلك',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  'تلكم': [{'word': 'تلكم',
#    'vocalized': 'تِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': '-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': ''}],
#  'أكتلكم': [{'word': 'أكتلكم',
#    'vocalized': 'أكَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أك-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أتلكم': [{'word': 'أتلكم',
#    'vocalized': 'أَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أ-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام'}],
#  'أبتلكم': [{'word': 'أبتلكم',
#    'vocalized': 'أَبِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أفتلكم': [{'word': 'أفتلكم',
#    'vocalized': 'أَفَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أف-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف'}],
#  'أفبتلكم': [{'word': 'أفبتلكم',
#    'vocalized': 'أَفَبِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أفب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'أفكتلكم': [{'word': 'أفكتلكم',
#    'vocalized': 'أَفَكَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أفك-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'أفلتلكم': [{'word': 'أفلتلكم',
#    'vocalized': 'أَفَلِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أفل-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:معطوف:عطف:جر'}],
#  'ألتلكم': [{'word': 'ألتلكم',
#    'vocalized': 'أَلِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أل-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر'}],
#  'أوتلكم': [{'word': 'أوتلكم',
#    'vocalized': 'أَوَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أو-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:استفهام'}],
#  'أوبتلكم': [{'word': 'أوبتلكم',
#    'vocalized': 'أَوَبِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أوب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'أوكتلكم': [{'word': 'أوكتلكم',
#    'vocalized': 'أَوَكَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أوك-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'أولتلكم': [{'word': 'أولتلكم',
#    'vocalized': 'أَوَلِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'أول-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'استفهام:جر:معطوف:عطف'}],
#  'بتلكم': [{'word': 'بتلكم',
#    'vocalized': 'بِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'ب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'فتلكم': [{'word': 'فتلكم',
#    'vocalized': 'فَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'ف-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'فبتلكم': [{'word': 'فبتلكم',
#    'vocalized': 'فَبِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'فب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فكتلكم': [{'word': 'فكتلكم',
#    'vocalized': 'فَكَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'فك-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'فلتلكم': [{'word': 'فلتلكم',
#    'vocalized': 'فَلِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'فل-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف:جر'}],
#  'كتلكم': [{'word': 'كتلكم',
#    'vocalized': 'كَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'ك-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'لتلكم': [{'word': 'لتلكم',
#    'vocalized': 'لِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'ل-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'جر'}],
#  'وتلكم': [{'word': 'وتلكم',
#    'vocalized': 'وَتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'و-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'معطوف:عطف'}],
#  'وبتلكم': [{'word': 'وبتلكم',
#    'vocalized': 'وَبِتِلْكُم',
#    'type': 'اسم',
#    'category': 'اسم إشارة',
#    'original': 'تلكم',
#    'procletic': 'وب-',
#    'stem': 'تلكم',
#    'encletic': '-',
#    'tags': 'جر:معطوف:عطف'}],
#  ...}
