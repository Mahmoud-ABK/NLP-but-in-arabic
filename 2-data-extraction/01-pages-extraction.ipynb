# %% [markdown]
# # Pages extraction

# %%
import pandas as pd 
import numpy as np
import tqdm 
tqdm.tqdm.pandas()

# %%
raw = pd.read_csv("00-raw.csv")

# %%
raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1635 entries, 0 to 1634
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   article_id     1635 non-null   int64
#  1   title          48 non-null     object
#  2   title_en       192 non-null    object
#  3   abstract_ar    0 non-null      float64
#  4   abstract_en    0 non-null      float64
#  5   general_field  1446 non-null   object
#  6   field          0 non-null      float64
#  7   authors        206 non-null    object
#  8   authors_en     0 non-null      float64
#  9   publish_date   0 non-null      float64
#  10  source         1635 non-null   object
#  11  path           1635 non-null   object
# dtypes: float64(5), int64(1), object(6)
# memory usage: 153.4+ KB

# %%
raw.head()
# Out:
#    article_id                                              title  \
# 0           1  درجة اكتساب طلبة كلية التربية بجامعة السلطان ق...
# 1           2  القيادة الاستباقية وعلاقتها بإدارة مخاطر البيئ...
# 2           3  درجة ممارسة معلمي اللغة العربية لمهارات التذوق...
# 3           4  تحليل محتوى منهاج الرياضيات للصف الثامن من مرح...
# 4           5  تصميم تعليمي وفق التعلم الخبراتي وأثره في التح...
#
#                                             title_en  abstract_ar  \
# 0  The Level of Acquisition of Action Research Sk...          NaN
# 1  Proactive Leadership and its Relationship to S...          NaN
# 2  The Degree to Which Arabic Language Teachers P...          NaN
# 3  Analysis of the content of the mathematics cur...          NaN
# 4  Educational design based on experiential learn...          NaN
#
#    abstract_en general_field  field  \
# 0          NaN           NaN    NaN
# 1          NaN           NaN    NaN
# 2          NaN           NaN    NaN
# 3          NaN           NaN    NaN
# 4          NaN           NaN    NaN
#
#                                             authors  authors_en  publish_date  \
# 0                                    ["نور النجار"]         NaN           NaN
# 1  ["لانا عبد المولى العنزي", "محمد عبود الحراحشة"]         NaN           NaN
# 2                           ["أمل مد الله الشعراء"]         NaN           NaN
# 3                                     ["ريتا سعيد"]         NaN           NaN
# 4                             ["سلوى محسن العامري"]         NaN           NaN
#
#   source                      path
# 0    AJP  finalpdfs/AJP_1337_1.pdf
# 1    AJP  finalpdfs/AJP_1338_2.pdf
# 2    AJP  finalpdfs/AJP_1339_3.pdf
# 3    AJP  finalpdfs/AJP_1340_4.pdf
# 4    AJP  finalpdfs/AJP_1341_5.pdf

# %% [markdown]
# removing some abnormalities in authors columns

# %%
data = raw.copy()

# %%
data["authors"] = data["authors"].str.replace("1","")
data["authors"] = data["authors"].str.replace(",2","")
data["authors"] = data["authors"].str.replace("*","")
data["authors"] = data["authors"].str.replace("&",",")
data["authors"] = data["authors"].str.replace("/",",")
data["authors"] = data["authors"].str.replace("\u200c","")

# %%
data["authors"].tolist()
# Out:
# ['["نور النجار"]',
#  '["لانا عبد المولى العنزي", "محمد عبود الحراحشة"]',
#  '["أمل مد الله الشعراء"]',
#  '["ريتا سعيد"]',
#  '["سلوى محسن العامري"]',
#  '["رحمة علي البدوي", "سيف ناصر المعمري"]',
#  '["فيصل الراوي طايع"]',
#  '["أحمد علي طلب"]',
#  '["أحمد بن موسى حنتول"]',
#  '["ثنــاء هاشـم محمد"]',
#  '["حامــد سعيـد الجبـر"]',
#  '["صالحـة حنــس خلـف"]',
#  '["عنتر محمد أحمد"]',
#  '["عيسـى بن فـرج العزيزي"]',
#  '["منى مصطفى كمال محمد"]',
#  '["هشام محمد الخولي"]',
#  '["حنـان البـدري كمـال"]',
#  '["هبه إبراهيم"]',
#  '["عبيد مزعل عبيد الحربي"]',
#  '["محمد محمود عبدالوهاب"]',
#  '["Fayyad Muhammad Hani Bayan"]',
#  '["Khalil Almabrouk , Hamedi Adnan"]',
#  '["عبد الله بن حميد بن محارب الجهني,د. علي عمر عبدالله جفري"]',
#  '["علا على آل عسوج"]',
#  '["أ.,tنفيسة سعيدة"]',
#  '["د. ديمة إبراهيم نوارة"]',
#  '["منال حضيض الشاطري"]',
#  '["هاجر بنت فارس الشهري,أنفال بنت مسعود القحطاني,د. آمال فلمبان"]',
#  '["د. يوسف محمود شاكر الشطي"]',
#  '["هلا العتيبي"]',
#  '["صالح خلف العنزي,رهام مساعد الجارالله,عبد المجيد علي الفريدي"]',
#  '["Hussam Ahmad Hlaak", "Ali Alhousain Aleid", "Attia Al-Huseyin"]',
#  '["Tarek Jarjoura Chahine"]',
#  '["AI Hexu"]',
#  '["Amera Eid Alsaadi"]',
#  '["Abubakr Eltigani Elhag"]',
#  '["Rahaf Hmeed Alotaibi", "Fatima kobibi Bendenia"]',
#  '["Ahmed Chebli"]',
#  '["Fatima Ali Abdullah Abbas"]',
#  '["Alia Ali Saeed Alketbi", "Muhammad Hilmi Abdullah Jaafar"]',
#  '["Faris Omar Batawi", "Doaa Hassan Toweirqie"]',
#  '["Ashwaq Abdulhakeem Alsabaan"]',
#  '["Sara Saad Al-Dawsari", "Sadiq Ali Mubarak Al-Shuwaikhat"]',
#  '["Samy Garad Abu Freach"]',
#  '["Jehad Faiz Al-Islam"]',
#  '["Rayan Abdelazeem Haboub", "Khalid Hamid Bilal"]',
#  '["Turki Mohammed Habkoor Almoharraq"]',
#  '["Mohamed Elzin Mohamed Ahmed Ibrahim"]',
#  '["Mohamed El-Fazziki", "Fatima Ghmimed", "Jawad El-Bazwi", "Abdelouahed Bouberria"]',
#  '["Reda El-Yazidi"]',
#  '["Mohamed Hanafy Abdullah Morsy"]',
#  '["Assadik Ahmad Adam", "Mahamat Saleh Daway"]',
#  '["Rimah Mudawi Mansour"]',
#  '["Abdelouahed Bouberria", "Abdelhafid Hammimi", "Mohammed Abahrour", "Mohammed Errafik"]',
#  '["Wasaef Ali Bakhashwain", "Lara Zainalabdien Serri", "Mohamed GadElmawla Owies"]',
#  '["Mouza Said Al-Kharusi"]',
#  '["Ibrahim Youssif"]',
#  '["Mohamed Elzin Mohamed Ahmed Ibrahim"]',
#  '["Mariam Farhan Alfifi", "Ghada Owaid Awad Al-Sahli"]',
#  '["Abdelilah El-Alami", "Jaouad El-Bazoui", "Abdelouahed Bouberria"]',
#  '["Khaldoun Abdul Samad"]',
#  '["Ali Mohammed Qader"]',
#  '["Ahmed Farouk Ali", "Elsayed Eid", "Heba Alhadad"]',
#  '["Inaam Eid Mohammad Zaatrh", "Iyad Selim AbdulRazzaq Alhallaq"]',
#  '["Farida Ezzaghari"]',
#  '["Mohamed Senhaji", "Mohamed Abahrour", "Mostafa Hmamouchi", "Younes Abahrour"]',
#  '["Mohammed Elsmani Abdelrahman"]',
#  '["Hind Saad Alrashid"]',
#  '["Sekina Mohamed Mohamed Abd El Halim", "Amal Abdelaziz Mohamed Ghazy"]',
#  '["Manal Eid Sanusi Abjabal", "Foton Fouad Abdulkadir Fayoumi"]',
#  '["Rayan AbdulAziz Iraqi", "Shaheen Sulaiman Al-Abdali", "Mansour Talal Abid Alansari"]',
#  '["Shaker Abdullah Alsharif"]',
#  '["Osama Matar", "Reem Jawabreh", "Haya Radwan", "Abedelrahman Alhajhamad", "Mohammad Ayyash", "Sherin Kaleef", "Thaher Gharabeh", "Ashraf Abualrob", "Aseel Halabi", "Diya Abu Shomer"]',
#  '["Basheer Saleh Abdallah"]',
#  '["Brooj Nasser Abdullah Alsaqer"]',
#  '["Salem Khalil Nassr", "Doaa Zayed"]',
#  '["Khalid Ismail Nayif Al-Hamadani"]',
#  '["Abdulkarim Mohammad Alseadoon", "Geoffrey Nash"]',
#  '["Badereldin Ali Hamed Mohammed"]',
#  '["Nadha Mutlaq ALbogami"]',
#  '["Hakima Mansour Ahmed Khoshafah"]',
#  '["Hameed Aadm Ali Qushaimh"]',
#  '["Randa Mounir Elkherbaway", "Samar Ahmed Kanona", "Ngawha Kamel Bosiala"]',
#  '["Abrar Hashim Alattas", "Hana Abdullah Alamodi"]',
#  '["Habiba Nakhli"]',
#  '["Samar Gamal Al-Habbari"]',
#  '["Bandar Abdullah Al-Saud", "Abdulhamid Abdurahman Al-Abduljabbar"]',
#  '["Maha Dahawi Al-Shamari"]',
#  '["Yuan Linxian"]',
#  '["Adel Ahmed Abdullah Al-Mekhlafy", "Abdusalam Mohammed Ghaleb Al-Ghrafy"]',
#  '["Suhair Adel Abdulamir"]',
#  '["Suad Mawloud Zali"]',
#  '["Hala Ali Fergany", "Amani Saeed Alghamdi", "Amsha Zayed Almutairi"]',
#  '["Muhammad Saud Al-Khathlan", "Turki Abdel Aziz Al-Turki", "Anwar Ibrahim Al-Afnan", "Bandar Abdullah Al-Zoghaibi", "AbdulRahman Zabin Al-Mutairi", "Ibrahim Mohamed Bagader", "Raghad AbdelKarim Abdo", "Safia Mohammed Al-Dosari", "Abdullah Zabin Al-Mutairi", "Wafaa Daoud Al-Jareed", "Youssef Saleh Al-Haidan"]',
#  '["Mohammed Ahmad Asiri"]',
#  '["Jehad Feyzolaslam"]',
#  '["Amal Mohamed Toheri"]',
#  '["Fathi Abbas Khalaf", "Heba Muwafak Younis AlRawas"]',
#  '["Mahmoud Jamal Rayyan"]',
#  '["Khalid Hadi Hameed Al-Jourany"]',
#  '["Mahasin Abdulqadir Hasan"]',
#  '["Mohammed Asaad Diab Ewaiwi"]',
#  '["Manal Naji Khaleel"]',
#  '["Imtithal Mergny Mohammed Ahmed", "Afra Hashim Abdelateef"]',
#  '["Sabah Kara"]',
#  '["Ali Gharamah Alshehri"]',
#  '["AbdulJabbar Ahmed Al-Amlah"]',
#  '["Mshari Matar Alshamari", "Abdullah Salem Alzou’bi"]',
#  '["Iman Madallah Althbeitat Alamro"]',
#  '["Oula Ali Hakeem", "Sarra Al-Habib Ouerghi"]',
#  '["Ahmed Ali Al-Abed Al-Azeez", "Yaseen Ali Al-Maqosi"]',
#  '["Assadik Ahmad Adam"]',
#  '["Omar Mahmoud Nattouf", "Mohammad Mahmoud Amer"]',
#  '["Nader Mahmoud Taffach"]',
#  '["Haneen Shaker Al- Sharif"]',
#  '["Saad Jihad ATTIYA"]',
#  '["Namer Hasan Ebou"]',
#  '["Sahar Faisal Al-haj Rabye,\xa0Haytham Arabi"]',
#  '["Dema Ahmad Al-shakh,\xa0Mohamed Deribati, Ahmad Younso"]',
#  '["Malik Rehab Al- Azza, Ezzat Moh’d Hijab"]',
#  '["Bassam Khaled Al- Shawi,\xa0Zainab Walid Hayek"]',
#  '["Najeya Ali Rashid Alkharji"]',
#  '["Hadeel Mohammad Darwish, Muhammad Mazyad Drybati, Mounzer Hasan Boubou"]',
#  '["Rana M.Salah Eddin Mousa,\xa0Ali Muhammed Asa\'ad"]',
#  '["Omar Issa Fatafta"]',
#  '["Hasan Morshed Al-Mohamad,\xa0Isam Derar Al-Kousa"]',
#  '["Basheer Thabit Mohammed,\xa0Lateef Mahmoud Mohammed Al-Ghariri"]',
#  '["Mohamed Salem Harsha"]',
#  '["Mohamed Bashir Harba,\xa0Zamri Arifin,\xa0Hakim Zainal"]',
#  '["Sara Hassan Saeed Alzahrani"]',
#  '["Hamzah Abed-Alsalam Al-Khatatneh"]',
#  '["Zahraa Hussain Almosawi, Ahmad Fadhel Alkout, Mohammad Abd Alali Akbar"]',
#  '["Kawthar Muhammed Ali Jabara"]',
#  '["Alwah Hazam Muslah Aloreany"]',
#  '["Leena Ali Al-Jarrah, Mustafa Hasan Alqudah"]',
#  '["Rehab AbdUlmohsen Al- Qurashi"]',
#  '["Raweh Hamid Albar,\xa0Aisha Saleh Babssal"]',
#  '["Wadha Ahmad Mossad Al-Wargash"]',
#  '["Eisa Rabeeh Ahmad"]',
#  '["Awadh Ahmed Hasan"]',
#  '["Hosam Mohammad Al-Btoosh"]',
#  '["Dalal Abdullah Al-Harthy Al-Shareef"]',
#  '["Abdallah Ali Althory"]',
#  '["Ibrahem Humaidan Al- Mutairi"]',
#  '["Yaseen Ali Al- Maqosi"]',
#  '["Sherefah Ibrahim Bintaleb"]',
#  '["Frahan Ibrahim Al- Shammary, Yaseen Ali Al- Maqosi"]',
#  '["Salih Shuaib Salih,\xa0Maha Ahmed Ismail"]',
#  '["Odai Ahmad Qaqish,\xa0Mohammad Hashem Al-Momani"]',
#  '["Ryhanah Abdullah Al-Ansary"]',
#  '["Sahli Djelloul,\xa0Khaldi Hicham"]',
#  '["Ramzi Ben Mohamed Tej"]',
#  '["Elshahat Anwar Barakat"]',
#  '["Omar musa mahasneh, Othman Ibrahim bnitaha"]',
#  '["Fahad Ahmad Apopakr Almalki"]',
#  '["Fahad Khamis Ahmad Al-Fahdi"]',
#  '["Yasmine Abdullah Saad"]',
#  '["Othman Rashid Majeed"]',
#  '["Emad Hamdy Abdelsamed Abdelhamed"]',
#  '["Sami Mohammed Alqam"]',
#  '["Mamoun Abdelouahab, Tehirichi Abdelhafid"]',
#  '["Awwad Ahmad Aldandan"]',
#  '["Alaa Taref Garibeh"]',
#  '["Ahmad Abdalkareem Al- Molqi"]',
#  '["Ahyaf Abdel Azeze Burini"]',
#  '["Ahmed Mohammad Albzour"]',
#  '["Sarah Abdullah Alsabih"]',
#  '["Tamam Hamad Almnaizl"]',
#  '["Mohammed Yamani Mebirik"]',
#  '["Awad Mufleh Alkhazam"]',
#  '["Yousef saeed alghamdi"]',
#  '["Osama Mohamed El- Shishiny"]',
#  '["Cherif rym"]',
#  '["Mishal Fadhi al- Moghairi"]',
#  '["Sefaa Ali Al-maqabelah"]',
#  '["Soha Ali Salamah"]',
#  '["Ghareeb Abdulrahman Abdullah Al- Adyani"]',
#  '["Huda Qism Allah Mustafa"]',
#  '["Laila Othman Abdalla"]',
#  '["Mahmoud Khalif Khudair Obaid Hayani"]',
#  '["NUJUD ISMAIL ALANAZI, MOHD AZIDAN ABDUL JABAR, ABDURRAUF HASSAN, ABULHALIM BIN MOHAMAD"]',
#  '["Norah Abdullah Al-Sohebani,\xa0 Amal Othman Al- Atta"]',
#  '["Mohammed Babiker Alawad"]',
#  '["Abu Haneefa Omer AlShareef Ali Omer, Entesar Mahdadi Abdallah ElSiddig"]',
#  '["Deeaa Hussin Mouheb Aldeen"]',
#  '["Afrah Mohsen Al-salmi"]',
#  '["Hasan Mohammed Mfreg"]',
#  '["Khaled Abd alazaiz Hassan"]',
#  '["Najat Amhamad Hussein"]',
#  '["Eman  B. F. Al-Zbon", "Professor Dr. Yusra Al-Hasban"]',
#  '["Abdullah A. K. Dandan", "Yousef Bani Yassin"]',
#  '["Liwaa Khalil Al-Dasouqi"]',
#  '["alaa harahsheh", "Ziyad  M. Al-Gonmeen"]',
#  '["Zaid Daher Khalaf Hazaimeh"]',
#  '["Lutfi Al-Masaeed", "Muhammad Al-Hawamdeh", "Muhammad Al-Harahsheh"]',
#  '["Yassin Ali Al-Maharmeh"]',
#  '["Ahmed  Bani Khalid", "Omar  Al-Adamat", "Ibrahim  Bani Khalid"]',
#  '["Raed Ahmad Al-Karimeen"]',
#  '["Musalm Al-Shorofat", "Mahmoud  Al-Meqdadi", "Mohammed Al-Hawamdeh"]',
#  '["Faten M. Abu Salah", "Mohammad AlZboon"]',
#  '["sohaib alrefai"]',
#  '["Israa A. Al-Adwan", "Ferial Abu Awwad"]',
#  '["Shorouq H. Al-Amash", "Hamoud M. Al-Olimat", "Mamoun  Al-Zbon"]',
#  '["alia Al-oweidi", "Randa A. Barakat"]',
#  '["Muhammad Ali Alhayek", "Dhaifallah Aleimat"]',
#  '["Safa Al Olimat"]',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  ...]

# %%
data.isnull().sum()
# Out:
# article_id          0
# title            1587
# title_en         1443
# abstract_ar      1635
# abstract_en      1635
# general_field     189
# field            1635
# authors          1429
# authors_en       1635
# publish_date     1635
# source              0
# path                0
# dtype: int64

# %%
data.to_csv('01-data.csv', index=False)

# %% [markdown]
# # Step 1 Extracting Necessary Pages

# %% [markdown]
# ## Test for one pdf

# %%
from utils.firstpages import extract_first_three_pages , extract_first_two_pages_ocr

extract_first_three_pages(data['path'][0])
extract_first_two_pages_ocr(data['path'][20])
# Out:
# {'page1': 'دتمل\n\nالإصدار السابع — العدد ستة وستون\nتاريخ الإصدار: 2 - نيسان - 2024م\n\nwww.ajsp.net\n\nISSN: 2663-5798 || Arab Journal for Scientific Publishing\n\n2 539 سر حك ون سد مسدب \u200eFem\u200f هه \u200eINVES Gamo\u200f\n\n“The Ethics of AI: Navigating the Moral Dilemmas of Artificial\nIntelligence”\n\nResearcher:\n\nFayyad Muhammad Hani Bayan\n\nArab Journal for Scientific Publishing (AJSP) ISSN: 2663-5798',
#  'page2': "Wo!\n\nالإصدار السابع — العدد ستة وستون\nتاريخ الإصدار: 2 - نيسان - 2024م\n\nwww.ajsp.net\n\nISSN: 2663-5798 || Arab Journal for Scientific Publishing\n\nIN} :RTIOOL 5 Fone eres \u200fشمصة\u200e pe) SB \u200fلود\u200e EBSCO ©\n\nAbstract:\n\nThe significance of ethics in artificial intelligence (AI) cannot be overstated, as it encompasses the foundational principles\nguiding the responsible creation, deployment, and management of AI technologies. As AI systems increasingly permeate\nevery facet of our lives—from healthcare and education to security and entertainment—their decisions and actions have\nprofound implications not only on individual rights and privacy but also on societal norms and values. Ethical considerations\nin AI are paramount to ensure that these technologies enhance human well-being, uphold fairness, and protect freedoms,\nrather than perpetuate biases, exacerbate inequalities, or undermine democratic institutions. The importance of AI ethics lies\nin its ability to provide a framework for navigating the complex moral dilemmas presented by AI, such as the balance between\ninnovation and regulation, the protection of individual privacy versus the benefits of big data, and the prevention of AI\nmisuse. By foregrounding ethical principles, stakeholders—including developers, policymakers, and users—can work\ntowards the development of AI technologies that are not only technologically advanced but also socially responsible and\naligned with human values. This emphasis on ethics ensures that as AI systems become more autonomous and integral to our\ndaily lives, they do so in a manner that is transparent, accountable, and inclusive, thereby fostering trust and confidence in\ntheir widespread adoption and use.\n\nThe advent of new AI technologies brings to light a series of emerging ethical dilemmas that challenge existing frameworks\nand demand novel considerations. One of the forefront issues is the development of advanced autonomous systems, such as\nself-driving vehicles and autonomous weapons, which raise significant concerns about decision-making in scenarios\ninvolving human safety and the delegation of moral responsibility. Furthermore, the rapid advancement in generative AI\ntechnologies, capable of producing highly realistic text, images, and videos, introduces dilemmas related to authenticity,\nmisinformation, and the protection of intellectual property. These technologies blur the lines between reality and fabrication,\npotentially enabling the creation of convincing fake content that can undermine trust in media, influence elections, and violate\npersonal rights. Another emerging dilemma is the use of AI in predictive policing and judicial sentencing, where algorithms\nmight perpetuate systemic biases, affecting marginalized communities disproportionately. Moreover, the increasing\nintegration of AI in biotechnology, including gene editing and neurotechnology, presents profound ethical questions\nregarding consent, privacy, and the fundamental nature of human identity and biological integrity. These dilemmas\nunderscore the urgent need for an adaptive ethical framework that can address the nuances of these technologies, ensuring\nthat AI development is guided by principles that prioritize human rights, dignity, and ethical integrity in the face of\nunprecedented technological capabilities.\n\nTo navigate the ethical complexities introduced by AI, a multifaceted approach incorporating regulatory frameworks, ethical\nguidelines, and proactive governance models is essential. Proposed solutions and frameworks should start with the\nestablishment of international and national regulations that set clear boundaries for AI development and usage, ensuring that\nAI technologies are deployed in ways that respect human rights, privacy, and dignity. These regulations could be\ncomplemented by industry-specific standards and codes of conduct that provide detailed guidance on ethical AI practices in\nvariou ...

# %% [markdown]
# ## Extract pages

# %%
batch_size = 100  
num_batches = int(np.ceil(len(data) / batch_size))

for batch_idx in range(num_batches):
    start_idx = batch_idx * batch_size
    end_idx = min((batch_idx + 1) * batch_size, len(data))
    batch = data.iloc[start_idx:end_idx]
    if 'path' in batch.columns:
        pages = batch['path'].progress_apply(extract_first_two_pages_ocr).tolist()
        data.loc[batch.index, ['page1', 'page2']] = pd.DataFrame(pages, index=batch.index)
        data.to_csv(f"step1_progress_batch_{batch_idx}.csv", index=False)

if 'path' in data.columns:
    data = data.drop(columns=["path"])
# Out:
# 100%|██████████| 100/100 [10:48<00:00,  6.48s/it]
# 100%|██████████| 100/100 [10:32<00:00,  6.33s/it]
# 100%|██████████| 100/100 [12:47<00:00,  7.68s/it]
# 100%|██████████| 100/100 [15:05<00:00,  9.06s/it]
# 100%|██████████| 100/100 [08:56<00:00,  5.37s/it]
# 100%|██████████| 100/100 [13:13<00:00,  7.93s/it]
# 100%|██████████| 100/100 [16:06<00:00,  9.66s/it]
# 100%|██████████| 100/100 [09:18<00:00,  5.58s/it]
# 100%|██████████| 100/100 [15:31<00:00,  9.31s/it]
# 100%|██████████| 100/100 [12:32<00:00,  7.53s/it]
# 100%|██████████| 100/100 [09:39<00:00,  5.80s/it]
# 100%|██████████| 100/100 [15:35<00:00,  9.36s/it]
# 100%|██████████| 100/100 [10:55<00:00,  6.55s/it]
# 100%|██████████| 100/100 [09:55<00:00,  5.96s/it]
# 100%|██████████| 100/100 [15:18<00:00,  9.18s/it]
# 100%|██████████| 100/100 [11:30<00:00,  6.90s/it]
# 100%|██████████| 35/35 [02:10<00:00,  3.72s/it]

# %%
data.to_csv('02-extracted-pages.csv', index=False)

# %%
import re

def clean_page_text(text):
    # Remove all unicode control characters except \n and regular spaces
    # Remove unnecessary spaces (multiple spaces to single space, strip leading/trailing)
    if not isinstance(text, str):
        return text
    # Remove unicode control characters except \n and space
    text = re.sub(r'[^\S\r\n ]+', '', text)
    # Replace multiple spaces with a single space
    text = re.sub(r' +', ' ', text)
    # Strip leading/trailing spaces
    text = text.strip()
    return text

for col in ['page1', 'page2']:
    data[col] = data[col].apply(clean_page_text)

# %%
def remove_decorative_punctuations(text):
    if not isinstance(text, str):
        return text
    # Remove common decorative punctuations and repeated dots
    text = re.sub(r'[•●▪♦■★☆※…—–―–‐‑⁃⁄⁎⁑⁂⁕⁖⁗⁘⁙⁚⁛⁜⁝⁞]', '', text)
    text = re.sub(r'[.]{3,}', '.', text)  # Replace 3 or more consecutive dots with a single dot
    text = re.sub(r'[_~^`]+', '', text)  # Remove underscores, tildes, etc.
    text = re.sub(r'[“”‘’]', '', text)   # Remove fancy quotes
    text = re.sub(r'[=]+', '', text)     # Remove repeated equals
    text = re.sub(r'[\u2022-\u2023\u25A0-\u25FF]', '', text)  # Remove unicode bullets/squares
    return text.strip()

for col in ['page1', 'page2']:
    data[col] = data[col].apply(remove_decorative_punctuations)

# %%
data.head(2)
# Out:
#    article_id                                              title  \
# 0           1  درجة اكتساب طلبة كلية التربية بجامعة السلطان ق...
# 1           2  القيادة الاستباقية وعلاقتها بإدارة مخاطر البيئ...
#
#                                             title_en  abstract_ar  \
# 0  The Level of Acquisition of Action Research Sk...          NaN
# 1  Proactive Leadership and its Relationship to S...          NaN
#
#    abstract_en general_field  field  \
# 0          NaN           NaN    NaN
# 1          NaN           NaN    NaN
#
#                                             authors  authors_en  publish_date  \
# 0                                    ["نور النجار"]         NaN           NaN
# 1  ["لانا عبد المولى العنزي", "محمد عبود الحراحشة"]         NaN           NaN
#
#   source                                              page1  \
# 0    AJP  Association of Ar ab Univ ersities Journal for...
# 1    AJP  Association of Ar ab Univ ersities Journal for...
#
#                                                page2  \
# 0  .مجمة اتحاد الجامعات العربية لمتربية وعمم النف...
# 1  القيادة االستباقية وعالقتها بإدارة مخاطر البيئ...
#
#                                                page3
# 0  درجة اكتساب طمبة كمية التربية بجامعة السمطان ق...
# 1  .مجلة اتحاد الجامعات العربية للتربية وعلم النف...

# %%
data.to_csv('1-step1.csv', index=False)
