# %%
import pandas as pd 
import os

# %%
data=pd.read_csv("03-pages_cleaned.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1624 entries, 0 to 1623
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   article_id     1624 non-null   int64
#  1   title          39 non-null     object
#  2   abstract_ar    0 non-null      float64
#  3   authors        22 non-null     object
#  4   authors_en     175 non-null    object
#  5   general_field  1444 non-null   object
#  6   publish_date   0 non-null      float64
#  7   page1          1624 non-null   object
#  8   page2          1624 non-null   object
#  9   source         1624 non-null   object
#  10  path           1624 non-null   object
#  11  keywords       0 non-null      float64
# dtypes: float64(3), int64(1), object(8)
# memory usage: 152.4+ KB

# %%
output_dir = "./metadata-extraction/"
os.makedirs(output_dir, exist_ok=True)

chunk_size = 200
num_chunks = (len(data) + chunk_size - 1) // chunk_size  # ceiling division

for i in range(num_chunks):
    start = i * chunk_size
    end = start + chunk_size
    chunk = data.iloc[start:end]

    chunk_path = os.path.join(output_dir, f"chunk_{i}.csv")
    chunk.to_csv(chunk_path, index=False)

    print(f"Saved {chunk_path}")
# Out:
# Saved ./metadata-extraction/chunk_0.csv
# Saved ./metadata-extraction/chunk_1.csv
# Saved ./metadata-extraction/chunk_2.csv
# Saved ./metadata-extraction/chunk_3.csv
# Saved ./metadata-extraction/chunk_4.csv
# Saved ./metadata-extraction/chunk_5.csv
# Saved ./metadata-extraction/chunk_6.csv
# Saved ./metadata-extraction/chunk_7.csv
# Saved ./metadata-extraction/chunk_8.csv
