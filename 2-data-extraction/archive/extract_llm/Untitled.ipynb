# %%
from workflow import work

# %%
work()
# Out:
# [INFO] Starting workflow
# [INFO] Loading source CSV: /home/mahmoud/Engineering/isimm/ing2/data-treatment/prj-data-treatment/2-data-extraction/extract_llm/02-extracted-pages-with-tokens.csv
# [INFO] Output CSV not found → creating new one
#
# ...
# [ROW] Processing index=0 | article_id=1
# [CHECK] Field completeness:
#    - title        → 'درجة اكتساب طلبة كلية التربية …' | missing=False
#    - title_en     → 'The Level of Acquisition of Ac…' | missing=False
#    - abstract_ar  → <NA> | missing=True
#    - abstract_en  → <NA> | missing=True
#    - general_field → <NA> | missing=True
#    - authors      → '["نور النجار"]' | missing=False
# [DECISION] needs_llm = True
# [PINPOINT] source='AJP'
# [PINPOINT] Extracted text length = 1885
# [LLM] Calling LLM… this may take a while
# [LLM] LLM returned metadata
# [FILL] Missing fields filled from LLM
# ...

# %%
import pandas as pd

# %%
a=pd.read_csv("03-extracted-pages-with-tokens.filled.csv")

# %%
a["abstract_ar"][1]
# Out:
# 'علي تنمية مهارات استخدم التقويم «hall والاتجاه نحو حركات إصلاح تعلم العلوم, وقياس أثر ذلك علي أداء cadre واعتمد البحث المنهج التجريبي ذو التصميم القائم علي المجموعة الواحدة والتي تكونت من Lies )١15( وعلي التصميم ذو المجموعتين الضابطة والتجريبية لقياس أداء عينة( )١ تلميذاً بإدارة أسيوط التعليمية» وتضمنت أدوات البحث بطاقة ملاحظة مهارات استخدام المعلمين للتقويم البديل» ومقياس اتجاه المعلمين نحو حركات إصلاح التعليم» ومقياس تقدير ثم تطبيق أدوات البحث cae وقد أظهرت نتائج البحث وجود فروق GIS دلالة إحصائية بين متوسطات درجات معلمي المرحلة الابتدائية في التطبيقين القبلي والبعدي في كل من مقياس الاتجاه وبطاقة ملاحظة مهارات استخدام التفويم البديل لصالح التطبيق البعدي, ووجود فرق دال إحصائيا بين متوسطي درجات تلاميذ المجموعتين التجريبية( تلاميذ المعلمين المتدربين) والضابطة في التطبيق البعدي لمقياس تقدير الأداء لصالح المجموعة التجريبية'

# %%
a["title"][1]
# Out:
# 'فلسفة بناء المنهج متعدد التنخصصات(اكتشف) وأثره في تنمية مهارات استخدام التقويم البديل والاتجاه نحو حركات إصلاح مناهج العلوم وأداء تلاميذهم'
